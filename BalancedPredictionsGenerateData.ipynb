# %%
import pandas as pd
import numpy as np
import sqlite3
import re
from sklearn.cluster import KMeans

conn = sqlite3.connect("profiles.db")
cursor = conn.cursor()
cursor.execute("ATTACH DATABASE 'colleges.db' AS colleges")

# %%
df = pd.read_sql_query("SELECT * FROM colleges.university_profiles AS c JOIN profiles AS p ON c.school = p.school",conn)
max_index = len(df.index)

# %%
def get_type_map(df_column):
    return {t:i for i, t in enumerate(set(df_column))}

def convert_sat_to_act(sat):
    if np.isnan(sat):
        return np.nan
    sat_scores = np.array([990, 1060, 1140, 1210, 1270, 1330, 1390, 1450, 1510, 1560, 1620, 1680, 1740, 1800, 1860, 1920, 1980, 2020, 2080, 2140, 2220, 2290, 2380, 2410])
    return np.where(sat < sat_scores)[0][0] + 13
    
def combine_test_scores(x):
    if not np.isnan(x['act']):
        return x['act']/36.0
    sat = np.array([x['sat_m'], x['sat_r'], x['sat_w']])
    return convert_sat_to_act(3*sat[~np.isnan(sat)].mean())/36.0 if len(sat[np.isnan(sat)]) != 3 else np.nan

def convert_string(x):
    try:
        return int(x)
    except:
        return np.nan

def combine_avg_test_scores(x):
    if not np.isnan(convert_string(x['avg_act'])):
        return convert_string(x['avg_act'])/36.0
    sat = np.array([convert_string(x['sat_math']), convert_string(x['sat_reading']), convert_string(x['sat_writing'])])
    return convert_sat_to_act(3*sat[~np.isnan(sat)].mean())/36.0 if len(sat[np.isnan(sat)]) != 3 else np.nan

def map_statuses(x):
    status_map = {"Denied": 0, "Deferred": np.nan, "Wait-Listed": np.nan, "Accepted": 2, "Will Attend": 2}
    return status_map[x['status']]

def convert_class_rank(x):
    s = str(x['class_rank'])
    if " of " in s:
        return float(s[:s.index(" of ")])/float(s[s.index(" of ") + 4:])
    if "Top " in s:
        return float(s[4:s.index("%")])/100.0
    if "Bottom " in s:
        return float(s[7:s.index("%")])/100.0
    return np.nan

def convert_instate_tuition(x):
    if "<br>" in str(x['cost_attendance']):
        instate = x['cost_attendance'].split("<br>")[0]
        return instate[instate.index("$")+1:]
    else:
        return x['cost_attendance']

def convert_outstate_tuition(x):
    if "<br>" in str(x['cost_attendance']):
        outstate = x['cost_attendance'].split("<br>")[1]
        return outstate[outstate.index("$")+1:]
    else:
        return x['cost_attendance']

def get_tuition(x):
    return x['in_state_tuition'] if x['state'] == x['hs_state'] else x['out_state_tuition']

def map_hs_types(x):
    hs_type_map = {"Public": 0, "Private": 1, "Parochial": 2, "Home": 3}
    return hs_type_map[x['hs_type']]

def map_ins_types(x):
    ins_type_map = {"Public": 0, "Private": 1, "Private for-profit": 1, "&nbsp;": np.nan}
    return ins_type_map[x['institution_type']]

# %%
df = df.loc[:,~df.columns.duplicated()]
df.fillna(value=pd.np.nan, inplace=True)
df['avg_act'] = df['avg_act'].map(lambda x: str(x).strip('-'))
df['test_score'] = df.apply(combine_test_scores, axis=1)
df['avg_test_score'] = df.apply(combine_avg_test_scores, axis=1)
df['class_rank'] = df.apply(convert_class_rank, axis=1)
df['institution_type'] = df.apply(map_ins_types, axis=1)
df['in_state_tuition'] = df.apply(convert_instate_tuition, axis=1)
df['out_state_tuition'] = df.apply(convert_outstate_tuition, axis=1)
#df['tuition'] = df.apply(get_tuition, axis=1)
df['status'] = df.apply(map_statuses, axis=1)

for col in ['cost_attendance', 'city', 'sat_m', 'sat_r', 'sat_w', 'act', 'sat_math', 'sat_reading', 'sat_writing', 'avg_act', 'gpa_w']:
    df = df.drop(col, axis=1)
df = df.dropna()#subset=['test_score','avg_test_score','gpa_uw','class_rank','hs_state','hs_type','institution_type'])

df['hs_type'] = df.apply(map_hs_types, axis=1)
replace_columns = ['hs_state', 'state', 'gender', 'school']
for col in replace_columns:
    df[col].replace(get_type_map(df[col]), inplace=True)
    
dfc = df.copy()
df_plain = df.copy()
for col in ['avg_gpa','hs_state','school','hs_type','avg_test_score','state','average_freshman_aid','admission_rate','faculty_total','international_percent','institution_type','female_percentage','year','gender','status','eaed','legacy','athlete','in_state_tuition','out_state_tuition']:
    dfc = dfc.drop(col, axis=1)

def getNextTableIndex(index,j):
    isValid = False
    while(not isValid):
        try:
            dfc['class_rank'][index]
            return index, j+1
        except:
            index += 1

print("Setting up points")
points = []
i = 0
j=0
while i < 97686:
    i, j = getNextTableIndex(i,j)
    point = []
    for col in dfc.columns.values:
        point.append(dfc[col].get(i))
    points.append(point)
    i += 1
print("Done")
        
cluster = KMeans(n_clusters=1500, max_iter=500).fit(points)
# Out:
# Setting up points
# Done

# %%
print("Assigning clusters")
i = 0
j = 0
while i < 97686:
    label = cluster.labels_[j]
    i, j = getNextTableIndex(i,j)
    dfc.set_value(i, "cluster",label)
    i += 1
    
for col in ['gpa_uw', 'class_rank', 'test_score']:
    df = df.drop(col, axis=1)

df = df.join(dfc, how='outer')
df.dropna()
# Out:
# Assigning clusters
# /home/marclane/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
#        school  state avg_gpa average_freshman_aid admission_rate  \
# 0         411      1    3.30                11104             88
# 2         845     33    3.52                21500             73
# 3         845     33    3.52                21500             73
# 4         845     33    3.52                21500             73
# 5         845     33    3.52                21500             73
# 6         845     33    3.52                21500             73
# 7         845     33    3.52                21500             73
# 10        845     33    3.52                21500             73
# 12        845     33    3.52                21500             73
# 13        845     33    3.52                21500             73
# 15        845     33    3.52                21500             73
# 16        845     33    3.52                21500             73
# 17        845     33    3.52                21500             73
# 18        845     33    3.52                21500             73
# 19        845     33    3.52                21500             73
# 20        845     33    3.52                21500             73
# 21        845     33    3.52                21500             73
# 24        845     33    3.52                21500             73
# 25        845     33    3.52                21500             73
# 26        845     33    3.52                21500             73
# 27        845     33    3.52                21500             73
# 31        845     33    3.52                21500             73
# 34        845     33    3.52                21500             73
# 38        845     33    3.52                21500             73
# 39        845     33    3.52                21500             73
# 40        845     33    3.52                21500             73
# 42        845     33    3.52                21500             73
# 44        845     33    3.52                21500             73
# 45        845     33    3.52                21500             73
# 46        845     33    3.52                21500             73
# ...       ...    ...     ...                  ...            ...
# 97644     558     20    3.41                11840             53
# 97645     558     20    3.41                11840             53
# 97646     558     20    3.41                11840             53
# 97648     558     20    3.41                11840             53
# 97649     558     20    3.41                11840             53
# 97652     558     20    3.41                11840             53
# 97653     558     20    3.41                11840             53
# 97655     558     20    3.41                11840             53
# 97656     558     20    3.41                11840             53
# 97657     558     20    3.41                11840             53
# 97659     558     20    3.41                11840             53
# 97660     558     20    3.41                11840             53
# 97661     558     20    3.41                11840             53
# 97662     558     20    3.41                11840             53
# 97663     558     20    3.41                11840             53
# 97666     558     20    3.41                11840             53
# 97668     558     20    3.41                11840             53
# 97669     558     20    3.41                11840             53
# 97670     558     20    3.41                11840             53
# 97671     558     20    3.41                11840             53
# 97672     558     20    3.41                11840             53
# 97674     558     20    3.41                11840             53
# 97675     558     20    3.41                11840             53
# 97676     558     20    3.41                11840             53
# 97677     558     20    3.41                11840             53
# 97679     558     20    3.41                11840             53
# 97681     558     20    3.41                11840             53
# 97683     558     20    3.41                11840             53
# 97684     558     20    3.41                11840             53
# 97685     558     20    3.41                11840             53
#
#       faculty_total international_percent  institution_type female_percentage  \
# 0                37                   1.8               1.0              50.6
# 2               335                   4.0               1.0              68.4
# 3               335                   4.0               1.0              68.4
# 4               335                   4.0               1.0              68.4
# 5               335                   4.0               1.0              68.4
# 6               335                   4.0               1.0              68.4
# 7               335                   4.0               1.0              68.4
# 10              335                   4.0               1.0              68.4
# 12              335                   4.0               1.0              68.4
# 13              335                   4.0               1.0              68.4
# 15              335                   4.0               1.0              68.4
# 16              335                   4.0               1.0              68.4
# 17              335                   4.0               1.0              68.4
# 18              335                   4.0               1.0              68.4
# 19              335                   4.0               1.0              68.4
# 20              335                   4.0               1.0              68.4
# 21              335                   4.0               1.0              68.4
# 24              335                   4.0               1.0              68.4
# 25              335                   4.0               1.0              68.4
# 26              335                   4.0               1.0              68.4
# 27              335                   4.0               1.0              68.4
# 31              335                   4.0               1.0              68.4
# 34              335                   4.0               1.0              68.4
# 38              335                   4.0               1.0              68.4
# 39              335                   4.0               1.0              68.4
# 40              335                   4.0               1.0              68.4
# 42              335                   4.0               1.0              68.4
# 44              335                   4.0               1.0              68.4
# 45              335                   4.0               1.0              68.4
# 46              335                   4.0               1.0              68.4
# ...             ...                   ...               ...               ...
# 97644           165                   5.3               0.0              62.8
# 97645           165                   5.3               0.0              62.8
# 97646           165                   5.3               0.0              62.8
# 97648           165                   5.3               0.0              62.8
# 97649           165                   5.3               0.0              62.8
# 97652           165                   5.3               0.0              62.8
# 97653           165                   5.3               0.0              62.8
# 97655           165                   5.3               0.0              62.8
# 97656           165                   5.3               0.0              62.8
# 97657           165                   5.3               0.0              62.8
# 97659           165                   5.3               0.0              62.8
# 97660           165                   5.3               0.0              62.8
# 97661           165                   5.3               0.0              62.8
# 97662           165                   5.3               0.0              62.8
# 97663           165                   5.3               0.0              62.8
# 97660              35243    3.50    0.127273   0.722222   718.0
# 97661              35243    3.60    0.250000   0.638889  1312.0
# 97662              35243    3.77    0.100000   0.722222   707.0
# 97663              35243    2.90    0.500000   0.694444   255.0
# 97666              35243    3.11    0.250000   0.777778   385.0
# 97668              35243    3.68    0.071429   0.750000   270.0
# 97669              35243    2.90    0.059081   0.611111  1356.0
# 97670              35243    4.00    0.120301   0.694444   829.0
# 97671              35243    3.70    0.100000   0.888889   805.0
# 97672              35243    3.15    0.391796   0.472222   168.0
# 97674              35243    3.20    0.223247   0.527778  1011.0
# 97675              35243    3.75    0.100000   0.611111   753.0
# 97676              35243    3.24    0.240964   0.694444     7.0
# 97677              35243    3.65    0.198830   0.583333  1128.0
# 97679              35243    3.84    0.058685   0.750000  1325.0
# 97681              35243    3.37    0.562189   0.500000   471.0
# 97683              35243    3.30    0.205371   0.500000   844.0
# 97684              35243    3.75    0.250000   0.583333  1059.0
# 97685              35243    2.56    0.679702   0.527778   378.0
#
# [40494 rows x 24 columns]

# %%
generated_df = pd.DataFrame(columns=df.columns.values)
for label in set(cluster.labels_):
    for index, row in df[df.cluster == label].iterrows():
        temp = df[df.cluster == label].copy()
        temp['school'] = row['school']
        generated_df = generated_df.append(temp)
    print("Cluster {} done".format(label))
generated_df
# Out:
# Cluster 0 done
# Cluster 1 done
# Cluster 2 done
# Cluster 3 done
# Cluster 4 done
# Cluster 5 done
# Cluster 6 done
# Cluster 7 done
# Cluster 8 done
# Cluster 9 done
# Cluster 10 done
# Cluster 11 done
# Cluster 12 done
# Cluster 13 done
# Cluster 14 done
# Cluster 15 done
# Cluster 16 done
# Cluster 17 done
# Cluster 18 done
# Cluster 19 done
# Cluster 20 done
# Cluster 21 done
# Cluster 22 done
# Cluster 23 done
# Cluster 24 done
# Cluster 25 done
# Cluster 26 done
# Cluster 27 done
# Cluster 28 done
# Cluster 29 done
# Cluster 30 done
# Cluster 31 done
# Cluster 32 done
# Cluster 33 done
# Cluster 34 done
# Cluster 35 done
# Cluster 36 done
# Cluster 37 done
# Cluster 38 done
# Cluster 39 done
# Cluster 40 done
# Cluster 41 done
# Cluster 42 done
# Cluster 43 done
# Cluster 44 done
# Cluster 45 done
# Cluster 46 done
# Cluster 47 done
# Cluster 48 done
# Cluster 49 done
# Cluster 50 done
# Cluster 51 done
# Cluster 52 done
# Cluster 53 done
# Cluster 54 done
# Cluster 55 done
# Cluster 56 done
# Cluster 57 done
# Cluster 58 done
# Cluster 59 done
# Cluster 60 done
# Cluster 61 done
# Cluster 62 done
# Cluster 63 done
# Cluster 64 done
# Cluster 65 done
# Cluster 66 done
# Cluster 67 done
# Cluster 68 done
# Cluster 69 done
# Cluster 70 done
# Cluster 71 done
# Cluster 72 done
# Cluster 73 done
# Cluster 74 done
# Cluster 75 done
# Cluster 76 done
# Cluster 77 done
# Cluster 78 done
# Cluster 79 done
# Cluster 80 done
# Cluster 81 done
# Cluster 82 done
# Cluster 83 done
# Cluster 84 done
# Cluster 85 done
# Cluster 86 done
# Cluster 87 done
# Cluster 88 done
# Cluster 89 done
# Cluster 90 done
# Cluster 91 done
# Cluster 92 done
# Cluster 93 done
# Cluster 94 done
# Cluster 95 done
# Cluster 96 done
# Cluster 97 done
# Cluster 98 done
# Cluster 99 done
# Cluster 100 done
# Cluster 101 done
# Cluster 102 done
# Cluster 103 done
# Cluster 104 done
# Cluster 105 done
# Cluster 106 done
# Cluster 107 done
# Cluster 108 done
# Cluster 109 done
# Cluster 110 done
# Cluster 111 done
# Cluster 112 done
# Cluster 113 done
# Cluster 114 done
# Cluster 115 done
# Cluster 116 done
# Cluster 117 done
# Cluster 118 done
# Cluster 119 done
# Cluster 120 done
# Cluster 121 done
# Cluster 122 done
# Cluster 123 done
# Cluster 124 done
# Cluster 125 done
# Cluster 126 done
# Cluster 127 done
# Cluster 128 done
# Cluster 129 done
# Cluster 130 done
# Cluster 131 done
# Cluster 132 done
# Cluster 133 done
# Cluster 134 done
# Cluster 135 done
# Cluster 136 done
# Cluster 137 done
# Cluster 138 done
# Cluster 139 done
# Cluster 140 done
# Cluster 141 done
# Cluster 142 done
# Cluster 143 done
# Cluster 144 done
# Cluster 145 done
# Cluster 146 done
# Cluster 147 done
# Cluster 148 done
# Cluster 149 done
# Cluster 150 done
# Cluster 151 done
# Cluster 152 done
# Cluster 153 done
# Cluster 154 done
# Cluster 155 done
# Cluster 156 done
# Cluster 157 done
# Cluster 158 done
# Cluster 159 done
# Cluster 160 done
# Cluster 161 done
# Cluster 162 done
# Cluster 163 done
# Cluster 164 done
# Cluster 165 done
# Cluster 166 done
# Cluster 167 done
# Cluster 168 done
# Cluster 169 done
# Cluster 170 done
# Cluster 171 done
# Cluster 172 done
# Cluster 173 done
# Cluster 174 done
# Cluster 175 done
# Cluster 176 done
# Cluster 177 done
# Cluster 178 done
# Cluster 179 done
# Cluster 180 done
# Cluster 181 done
# Cluster 182 done
# Cluster 183 done
# Cluster 184 done
# Cluster 185 done
# Cluster 186 done
# Cluster 187 done
# Cluster 188 done
# Cluster 189 done
# Cluster 190 done
# Cluster 191 done
# Cluster 192 done
# Cluster 193 done
# Cluster 194 done
# Cluster 195 done
# Cluster 196 done
# Cluster 197 done
# Cluster 198 done
# Cluster 199 done
# Cluster 200 done
# Cluster 201 done
# Cluster 202 done
# Cluster 203 done
# Cluster 204 done
# Cluster 205 done
# Cluster 206 done
# Cluster 207 done
# Cluster 208 done
# Cluster 209 done
# Cluster 210 done
# Cluster 211 done
# Cluster 212 done
# Cluster 213 done
# Cluster 214 done
# Cluster 215 done
# Cluster 216 done
# Cluster 217 done
# Cluster 218 done
# Cluster 219 done
# Cluster 220 done
# Cluster 221 done
# Cluster 222 done
# Cluster 223 done
# Cluster 224 done
# Cluster 225 done
# Cluster 226 done
# Cluster 227 done
# Cluster 228 done
# Cluster 229 done
# Cluster 230 done
# Cluster 231 done
# Cluster 232 done
# Cluster 233 done
# Cluster 234 done
# Cluster 235 done
# Cluster 236 done
# Cluster 237 done
# Cluster 238 done
# Cluster 239 done
# Cluster 240 done
# Cluster 241 done
# Cluster 242 done
# Cluster 243 done
# Cluster 244 done
# Cluster 245 done
# Cluster 246 done
# Cluster 247 done
# Cluster 248 done
# Cluster 249 done
# Cluster 250 done
# Cluster 251 done
# Cluster 252 done
# Cluster 253 done
# Cluster 254 done
# Cluster 255 done
# Cluster 256 done
# Cluster 257 done
# Cluster 258 done
# Cluster 259 done
# Cluster 260 done
# Cluster 261 done
# Cluster 262 done
# Cluster 263 done
# Cluster 264 done
# Cluster 265 done
# Cluster 266 done
# Cluster 267 done
# Cluster 268 done
# Cluster 269 done
# Cluster 270 done
# Cluster 271 done
# Cluster 272 done
# Cluster 273 done
# Cluster 274 done
# Cluster 275 done
# Cluster 276 done
# Cluster 277 done
# Cluster 278 done
# Cluster 279 done
# Cluster 280 done
# Cluster 281 done
# Cluster 282 done
# Cluster 283 done
# Cluster 284 done
# Cluster 285 done
# Cluster 286 done
# Cluster 287 done
# Cluster 288 done
# Cluster 289 done
# Cluster 290 done
# Cluster 291 done
# Cluster 292 done
# Cluster 293 done
# Cluster 294 done
# Cluster 295 done
# Cluster 296 done
# Cluster 297 done
# Cluster 298 done
# Cluster 299 done
# Cluster 300 done
# Cluster 301 done
# Cluster 302 done
# Cluster 303 done
# Cluster 304 done
# Cluster 305 done
# Cluster 306 done
# Cluster 307 done
# Cluster 308 done
# Cluster 309 done
# Cluster 310 done
# Cluster 311 done
# Cluster 312 done
# Cluster 313 done
# Cluster 314 done
# Cluster 315 done
# Cluster 316 done
# Cluster 317 done
# Cluster 318 done
# Cluster 319 done
# Cluster 320 done
# Cluster 321 done
# Cluster 322 done
# Cluster 323 done
# Cluster 324 done
# Cluster 325 done
# Cluster 326 done
# Cluster 327 done
# Cluster 328 done
# Cluster 329 done
# Cluster 330 done
# Cluster 331 done
# Cluster 332 done
# Cluster 333 done
# Cluster 334 done
# Cluster 335 done
# Cluster 336 done
# Cluster 337 done
# Cluster 338 done
# Cluster 339 done
# Cluster 340 done
# Cluster 341 done
# Cluster 342 done
# Cluster 343 done
# Cluster 344 done
# Cluster 345 done
# Cluster 346 done
# Cluster 347 done
# Cluster 348 done
# Cluster 349 done
# Cluster 350 done
# Cluster 351 done
# Cluster 352 done
# Cluster 353 done
# Cluster 354 done
# Cluster 355 done
# Cluster 356 done
# Cluster 357 done
# Cluster 358 done
# Cluster 359 done
# Cluster 360 done
# Cluster 361 done
# Cluster 362 done
# Cluster 363 done
# Cluster 364 done
# Cluster 365 done
# Cluster 366 done
# Cluster 367 done
# Cluster 368 done
# Cluster 369 done
# Cluster 370 done
# Cluster 371 done
# Cluster 372 done
# Cluster 373 done
# Cluster 374 done
# Cluster 375 done
# Cluster 376 done
# Cluster 377 done
# Cluster 378 done
# Cluster 379 done
# Cluster 380 done
# Cluster 381 done
# Cluster 382 done
# Cluster 383 done
# Cluster 384 done
# Cluster 385 done
# Cluster 386 done
# Cluster 387 done
# Cluster 388 done
# Cluster 389 done
# Cluster 390 done
# Cluster 391 done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7e10f2e7f481> in <module>
#       4         temp = df[df.cluster == label].copy()
#       5         temp['school'] = row['school']
# ----> 6         generated_df = generated_df.append(temp)
#       7     print("Cluster {} done".format(label))
#       8 generated_df
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6209         return concat(to_concat, ignore_index=ignore_index,
#    6210                       verify_integrity=verify_integrity,
# -> 6211                       sort=sort)
#    6212
#    6213     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     224                        verify_integrity=verify_integrity,
#     225                        copy=copy, sort=sort)
# --> 226     return op.get_result()
#     227
#     228
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     421             new_data = concatenate_block_managers(
#     422                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 423                 copy=self.copy)
#     424             if not self.copy:
#     425                 new_data._consolidate_inplace()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5419         else:
#    5420             b = make_block(
# -> 5421                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    5422                 placement=placement)
#    5423         blocks.append(b)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals.py in concatenate_join_units(join_units, concat_axis, copy)
#    5577                 concat_values = concat_values.copy()
#    5578     else:
# -> 5579         concat_values = _concat._concat_compat(to_concat, axis=concat_axis)
#    5580
#    5581     return concat_values
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/concat.py in _concat_compat(to_concat, axis)
#     194                 to_concat = [x.astype('object') for x in to_concat]
#     195
# --> 196     return np.concatenate(to_concat, axis=axis)
#     197
#     198
#
# KeyboardInterrupt:

# %%
generated_df
# Out:
#       school state avg_gpa average_freshman_aid admission_rate faculty_total  \
# 284      559     1    3.33                22520             74           108
# 805      559    47    3.71                47010             68            26
# 1764     559    15    3.36                29388             72           127
# 2074     559    28    3.45                15530             79           459
# 2249     559    33    3.78                40705             43           467
# 9469     559    15    3.43                32640             52           298
# 24777    559    41    3.57                30669             69           163
# 25058    559    19    3.29                18778             68           164
# 26025    559    41    3.61                 8688             78          2212
# 26284    559    37    3.46                30926             71            78
# 26735    559     2    3.59                37388             78           345
# 31751    559     5    3.47                24020             77           654
# 36831    559    22    3.64                38374             29           793
# 37063    559    48    4.20                 9021             70           966
# 37427    559    30    3.70                20078             81           361
# 43879    559    14    3.36                 8288             81           961
# 53497    559    41    3.38                11138             88          1010
# 54332    559    36    3.67                38128             63           306
# 56082    559     8    3.69                43032             52           106
# 57375    559     2    3.30                10667             73           760
# 57914    559     2    3.40                11613             65           326
# 63055    559    48    3.19                29257             91           101
# 75639    559    45    3.90                13986             80           544
# 77576    559    44    3.93                41885             80           104
# 79009    559     9    4.26                11813             44          1830
# 80507    559    30    3.94                14137             77          1567
# 85634    559    48    3.40                12857             81           224
# 87728    559     9    3.62                 8990             65           435
# 90082    559    41    3.68                42174             56           165
# 92207    559     8    3.78                25071             87           133
# ...      ...   ...     ...                  ...            ...           ...
# 70285    160    20    3.76                52795             16          2133
# 71325    160    33    3.65                36410             46           735
# 72845    160    28    3.58                13628             61           439
# 75070    160    22    3.40                31104             83           400
# 76296    160    50    3.77                36505             66            80
# 76323    160    50    3.77                36505             66            80
# 76787    160    50    4.02                14735             23          1115
# 88367   4.00    0.100000   0.888889   392.0
# 88711   4.00    0.100000   0.888889   392.0
# 89248   4.00    0.082888   0.888889   392.0
# 90590   4.00    0.100000   0.888889   392.0
# 90681   3.99    0.100000   0.888889   392.0
# 92209   4.00    0.100000   0.888889   392.0
# 93024   4.00    0.100000   0.888889   392.0
# 93042   4.00    0.100000   0.888889   392.0
# 93121   4.00    0.100000   0.888889   392.0
# 93178   4.00    0.100000   0.888889   392.0
# 93279   4.00    0.100000   0.888889   392.0
# 93290   4.00    0.100000   0.888889   392.0
# 95229   4.00    0.100000   0.888889   392.0
#
# [1033828 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_predict
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.linear_model import LogisticRegression

k = 1

df0 = df[df.status == 0]
df2 = df[df.status == 2].sample(n = int(k*len(df0)))

dfg0 = generated_df[generated_df.status == 0]
dfg2 = generated_df[generated_df.status == 2].sample(n = int(k*len(dfg0)))

df_final = pd.concat([df0, df2])
dfg_final = pd.concat([dfg0, dfg2])

X = df_final.drop('status', axis=1)
Xg = dfg_final.drop('status', axis=1)

y = df_final['status']
yg = dfg_final['status']

scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

scaler = StandardScaler()
scaler.fit(Xg)
Xg = scaler.transform(Xg)

X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y)

X_train1 = np.append(X_train1,Xg)
y_train1 = np.append(y_train1,yg)

mlp = MLPClassifier(hidden_layer_sizes=(8,8,8),max_iter=1000)



# y_pred = cross_val_predict(mlp, X, y, cv = 4)

# print(classification_report(y,y_pred))

# logisticRegr = LogisticRegression()

# y_pred = cross_val_predict(logisticRegr, X, y, cv = 4)

# print(classification_report(y,y_pred))


mlp.fit(X_train1,y_train1)
predictions = mlp.predict(X_test1)
print(confusion_matrix(y_test1,predictions))
print(classification_report(y_test1,predictions))

# logisticRegr = LogisticRegression()
# logisticRegr.fit(X_train1, y_train1)
# score = logisticRegr.score(X_test1, y_test1)
# print("Logistic Regression Score: " + str(score))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64, object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/marclane/.local/lib/python3.6/site-packages/ipykernel_launcher.py:26: DataConversionWarning: Data with input dtype int64, float64, object were all converted to float64 by StandardScaler.
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype float64, object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/marclane/.local/lib/python3.6/site-packages/ipykernel_launcher.py:30: DataConversionWarning: Data with input dtype float64, object were all converted to float64 by StandardScaler.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-1ec3539fe8ba> in <module>
#      50
#      51
# ---> 52 mlp.fit(X_train1,y_train1)
#      53 predictions = mlp.predict(X_test1)
#      54 print(confusion_matrix(y_test1,predictions))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py in fit(self, X, y)
#     975         """
#     976         return self._fit(X, y, incremental=(self.warm_start and
# --> 977                                             hasattr(self, "classes_")))
#     978
#     979     @property
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py in _fit(self, X, y, incremental)
#     322                              hidden_layer_sizes)
#     323
# --> 324         X, y = self._validate_input(X, y, incremental)
#     325         n_samples, n_features = X.shape
#     326
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py in _validate_input(self, X, y, incremental)
#     912     def _validate_input(self, X, y, incremental):
#     913         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 914                          multi_output=True)
#     915         if y.ndim == 2 and y.shape[1] == 1:
#     916             y = column_or_1d(y, warn=True)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     745                     ensure_min_features=ensure_min_features,
#     746                     warn_on_dtype=warn_on_dtype,
# --> 747                     estimator=estimator)
#     748     if multi_output:
#     749         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     545                     "Reshape your data either using array.reshape(-1, 1) if "
#     546                     "your data has a single feature or array.reshape(1, -1) "
# --> 547                     "if it contains a single sample.".format(array))
#     548
#     549         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 0.1471315  -0.26070201 -0.03181542 ... -0.56743683  0.53141328
#   0.17949092].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
df

# %% [markdown]
# # To-do: Jake and Marco
# -
