# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("collegeprofiles.db")
cursor = conn.cursor()
print(pd.read_sql_query("select * from university_profiles", conn))
# Out:
#                                                 school avg_gpa sat_math  \
# 0                                   Bryn Athyn College    3.30      512
# 1                                   Adelphi University    3.52      578
# 2       Albany College of Pharmacy and Health Sciences    3.60     None
# 3                              Albertus Magnus College    2.60     None
# 4                                     Albright College    3.20      490
# 5                                    Alfred University    2.96      560
# 6                                    Allegheny College    3.48      604
# 7                                   DeSales University    3.29      556
# 8                                  Alvernia University    3.33     None
# 9                       American International College    2.91      450
# 10                             Sacred Heart University    3.48      572
# 11           St. Joseph's College - Long Island Campus    3.50      554
# ...
